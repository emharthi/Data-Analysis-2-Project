# %%
# import the important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df =pd.read_csv('Breast Cancer Wisconsin (Diagnostic).csv')
df
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0      17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1      20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2      19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3      11.42     20.38       77.58   386.1      0.14250       0.28390
# 4      20.29     14.34      135.10  1297.0      0.10030       0.13280
# ..       ...       ...         ...     ...          ...           ...
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  \
# ...

# %% [markdown]
# ***Data Exploration***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   radius1             569 non-null    float64
#  1   texture1            569 non-null    float64
#  2   perimeter1          569 non-null    float64
#  3   area1               569 non-null    float64
#  4   smoothness1         569 non-null    float64
#  5   compactness1        569 non-null    float64
#  6   concavity1          569 non-null    float64
#  7   concave_points1     569 non-null    float64
#  8   symmetry1           569 non-null    float64
#  9   fractal_dimension1  569 non-null    float64
#  10  radius2             569 non-null    float64
#  11  texture2            569 non-null    float64
#  12  perimeter2          569 non-null    float64
#  13  area2               569 non-null    float64
#  14  smoothness2         569 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# radius1               0
# texture1              0
# perimeter1            0
# area1                 0
# smoothness1           0
# compactness1          0
# concavity1            0
# concave_points1       0
# symmetry1             0
# fractal_dimension1    0
# radius2               0
# texture2              0
# perimeter2            0
# area2                 0
# smoothness2           0
# compactness2          0
# concavity2            0
# concave_points2       0
# symmetry2             0
# fractal_dimension2    0
# radius3               0
# texture3              0
# perimeter3            0
# area3                 0
# smoothness3           0
# compactness3          0
# concavity3            0
# concave_points3       0
# symmetry3             0
# fractal_dimension3    0
# Diagnosis             0
# dtype: int64

# %%
df.describe()
# Out:
#           radius1    texture1  perimeter1        area1  smoothness1  \
# count  569.000000  569.000000  569.000000   569.000000   569.000000
# mean    14.127292   19.289649   91.969033   654.889104     0.096360
# std      3.524049    4.301036   24.298981   351.914129     0.014064
# min      6.981000    9.710000   43.790000   143.500000     0.052630
# 25%     11.700000   16.170000   75.170000   420.300000     0.086370
# 50%     13.370000   18.840000   86.240000   551.100000     0.095870
# 75%     15.780000   21.800000  104.100000   782.700000     0.105300
# max     28.110000   39.280000  188.500000  2501.000000     0.163400
#
#        compactness1  concavity1  concave_points1   symmetry1  \
# count    569.000000  569.000000       569.000000  569.000000
# mean       0.104341    0.088799         0.048919    0.181162
# std        0.052813    0.079720         0.038803    0.027414
# min        0.019380    0.000000         0.000000    0.106000
# ...

# %%
df.tail(10)
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 559    11.51     23.93       74.52   403.5      0.09261       0.10210
# 560    14.05     27.15       91.38   600.4      0.09929       0.11260
# 561    11.20     29.37       70.67   386.0      0.07449       0.03558
# 562    15.22     30.62      103.40   716.9      0.10480       0.20870
# 563    20.92     25.09      143.00  1347.0      0.10990       0.22360
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  \
# 559     0.11120          0.04105     0.1388             0.06570  ...
# ...

# %%
print(df.dtypes)
# Out:
# radius1               float64
# texture1              float64
# perimeter1            float64
# area1                 float64
# smoothness1           float64
# compactness1          float64
# concavity1            float64
# concave_points1       float64
# symmetry1             float64
# fractal_dimension1    float64
# radius2               float64
# texture2              float64
# perimeter2            float64
# area2                 float64
# smoothness2           float64
# compactness2          float64
# concavity2            float64
# concave_points2       float64
# symmetry2             float64
# fractal_dimension2    float64
# radius3               float64
# texture3              float64
# perimeter3            float64
# area3                 float64
# smoothness3           float64
# compactness3          float64
# concavity3            float64
# concave_points3       float64
# symmetry3             float64
# fractal_dimension3    float64
# Diagnosis              object
# ...

# %% [markdown]
# ***Data Processing***

# %%
#After that, we will define feature (X:all columns) and target (y:Target variable (Diagnosis)) variables,
# and split the dataset into training and testing sets.
from sklearn.model_selection import train_test_split

X = df.drop('Diagnosis', axis=1) # we drop the Diagnosis column because this is the Target
y = df['Diagnosis']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=125
)

# %% [markdown]
# ***Model Building and Training***

# %%
# Bulid the model
from sklearn.naive_bayes import GaussianNB

model = GaussianNB() # we will use Gaussian Naive Bayes

model.fit(X_train, y_train); # training the model

# %% [markdown]
# ***Evaluation the Model***

# %%
# import some libraries
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    classification_report,
)

# %% [markdown]
# ***Cross-Validation***

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.naive_bayes import GaussianNB

X = df.drop('Diagnosis', axis=1) # we drop the Diagnosis column because this is the Target
y = df['Diagnosis']

k_folds = KFold(n_splits = 4)

scores = cross_val_score(model, X, y, cv = k_folds)

print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.88111888 0.93661972 0.96478873 0.96478873]
# Average CV Score:  0.9368290160543682
# Number of CV Scores used in Average:  4

# %%
y_pred = model.predict(X_test)

accuray = accuracy_score(y_pred, y_test)
f1 = f1_score(y_pred, y_test, average="weighted")

print("Accuracy:", accuray)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.9308510638297872
# F1 Score: 0.9316748003447021

# %%
labels = ["maligant", "benign"]
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();

# %%
print('\nClassification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            B       0.92      0.97      0.95       118
#            M       0.95      0.86      0.90        70
#
#     accuracy                           0.93       188
#    macro avg       0.94      0.92      0.92       188
# weighted avg       0.93      0.93      0.93       188

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt


y_prob = model.predict_proba(X_test)[:, 1]


fpr, tpr, thresholds = roc_curve(y_test.map({'M': 1, 'B': 0}), y_prob)


plt.plot(fpr, tpr, label='Naive Bayes (AUC = {:.2f})'.format(roc_auc_score(y_test.map({'M': 1, 'B': 0}), y_prob)))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ***Visualization***

# %%
# 1. Histograms for feature distribution
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
sns.histplot(data=df, x='radius1', hue='Diagnosis', multiple='stack', bins=30, kde=True)
plt.title('Distribution of Radius by Class Lable')
plt.xlabel('Radius 1')
plt.ylabel('Diagnosis')
plt.show()

# %%
# 3. Pair plot
sns.pairplot(df, hue='Diagnosis', vars=['radius2', 'texture2', 'perimeter2', 'area1'])
plt.suptitle('Pair Plot of Selected Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='radius2', y='texture2', hue='Diagnosis', style='Diagnosis', data=df, palette='deep')
plt.title('Scatter Plot: Radius2 vs.Texture2')
plt.xlabel('Radius2')
plt.ylabel('Texture2')
plt.legend(title='Class (0: Benign, 1: Malignant)')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='area2', y='perimeter2', hue='Diagnosis', style='Diagnosis', data=df, palette='deep')
plt.title('Scatter Plot: Area2 vs. Perimeter2')
plt.xlabel('Area2')
plt.ylabel('Perimeter2')
plt.legend(title='Class lable (0: Benign, 1: Malignant)')
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x='smoothness1', y='symmetry1', hue='Diagnosis', style='Diagnosis', data=df, palette='deep')
plt.title('Scatter Plot: Smoothness2 vs. Symmetry2')
plt.xlabel('Smoothness3')
plt.ylabel('Symmetry3')
plt.legend(title='Class Lable (0: Benign, 1: Malignant)')
plt.show()

# %%
# Pairwise scatter plots for selected features
selected_features = ['radius3', 'texture2', 'area2', 'perimeter1']
sns.pairplot(df[selected_features + ['Diagnosis']], hue='Diagnosis', palette='deep')
plt.suptitle('Pairwise Scatter Plots of Selected Features', y=1.02)
plt.show()
